# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

df= pd.read_csv("C:\\Users\\RAMESHKUMAR\\Downloads\\mol_diagnostic centers.csv")
df
# Out:
#                         State  No. Blocks with Rapid Molecular Diagnostics
# 0   Andaman & Nicobar Islands                                            4
# 1              Andhra Pradesh                                          206
# 2           Arunachal Pradesh                                           12
# 3                       Assam                                           33
# 4                       Bihar                                           60
# 5                  Chandigarh                                            3
# 6                Chhattisgarh                                           33
# 7        Dadra & Nagar Haveli                                            1
# 8                 Daman & Diu                                            2
# 9                       Delhi                                           27
# 10                        Goa                                            2
# ...

# %%
#Govt. molecular labs across INDIA
sns.catplot(data=df, kind="bar", x="No. Blocks with Rapid Molecular Diagnostics", y="State",height=10 )
plt.show()

# %%
df2= pd.read_csv("C:\\Users\\RAMESHKUMAR\\Downloads\\old age home.csv")
df2
# Out:
#                    State  Old Age Homes
# 0         Andhra Pradesh             68
# 1      Arunachal Pradesh              1
# 2                  Assam             18
# 3                  Bihar              4
# 4           Chhattisgarh              3
# 5                    Goa              0
# 6                Gujarat              4
# 7                Haryana              7
# 8       Himachal Pradesh              1
# 9        Jammu & Kashmir              0
# 10             Jharkhand              0
# 11             Karnataka             56
# 12                Kerala              9
# 13        Madhya Pradesh              7
# 14           Maharashtra             34
# 15               Manipur             19
# 16             Meghalaya              0
# 17               Mizoram              0
# 18              Nagaland              1
# 19                Odisha             41
# 20                Punjab              7
# 21                Sikkim              0
# ...

# %%
# Old age homes in India
sns.catplot(data=df2, kind="bar", x="Old Age Homes", y="State",height=10 )
plt.show()
